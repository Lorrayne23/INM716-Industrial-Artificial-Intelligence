# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from PIL import Image
import matplotlib.pyplot as plt
import torchvision

import torchvision.transforms as transforms
from torchvision.models import vgg19, VGG19_Weights

import copy

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.set_default_device(device)

# %%
# desired size of the output image
imsize = 512 if torch.cuda.is_available() else 128  # use small size if no GPU

loader = transforms.Compose([
    transforms.Resize(imsize),  # scale imported image
    transforms.ToTensor()])  # transform it into a torch tensor


def image_loader(image_name):
    image = Image.open(image_name)
    # fake batch dimension required to fit network's input dimensions
    image = loader(image).unsqueeze(0)
    return image.to(device, torch.float)


style_img = image_loader("./images/pablo_picasso.jpg")
content_img = image_loader("./images/burberry_t_shirt_01.png")

print(style_img.size(), content_img.size())

resize = torchvision.transforms.Resize(
    # (H, W)
    size=(1,4,176,128)
)

content_img = resize(content_img)


print(style_img.size(), content_img.size())

assert style_img.size() == content_img.size(), \
    "we need to import style and content images of the same size"
# Out:
# torch.Size([1, 3, 176, 128]) torch.Size([1, 4, 174, 128])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 21
#      17 content_img = image_loader("./images/burberry_t_shirt_01.png")
#      19 print(style_img.size(), content_img.size())
# ---> 21 resize = torchvision.transforms.Resize(
#      22     # (H, W)
#      23     size=(1,4,176,128)
#      24 )
#      26 content_img = resize(content_img)
#      29 print(style_img.size(), content_img.size())
#
# File /opt/anaconda3/lib/python3.12/site-packages/torchvision/transforms/transforms.py:336, in Resize.__init__(self, size, interpolation, max_size, antialias)
#     334     raise TypeError(f"Size should be int or sequence. Got {type(size)}")
#     335 if isinstance(size, Sequence) and len(size) not in (1, 2):
# --> 336     raise ValueError("If size is a sequence, it should have 1 or 2 values")
#     337 self.size = size
#     338 self.max_size = max_size
#
# ValueError: If size is a sequence, it should have 1 or 2 values

# %%
unloader = transforms.ToPILImage()  # reconvert into PIL image

plt.ion()

def imshow(tensor, title=None):
    image = tensor.cpu().clone()  # we clone the tensor to not do changes on it
    image = image.squeeze(0)      # remove the fake batch dimension
    image = unloader(image)
    plt.imshow(image)
    if title is not None:
        plt.title(title)
    plt.pause(0.001) # pause a bit so that plots are updated


plt.figure()
imshow(style_img, title='Style Image')

plt.figure()
imshow(content_img, title='Content Image')

# %%
class ContentLoss(nn.Module):

    def __init__(self, target,):
        super(ContentLoss, self).__init__()
        # we 'detach' the target content from the tree used
        # to dynamically compute the gradient: this is a stated value,
        # not a variable. Otherwise the forward method of the criterion
        # will throw an error.
        self.target = target.detach()

    def forward(self, input):
        self.loss = F.mse_loss(input, self.target)
        return input

# %%
def gram_matrix(input):
    a, b, c, d = input.size()  # a=batch size(=1)
    # b=number of feature maps
    # (c,d)=dimensions of a f. map (N=c*d)

    features = input.view(a * b, c * d)  # resize F_XL into \hat F_XL

    G = torch.mm(features, features.t())  # compute the gram product

    # we 'normalize' the values of the gram matrix
    # by dividing by the number of element in each feature maps.
    return G.div(a * b * c * d)

# %%
class StyleLoss(nn.Module):

    def __init__(self, target_feature):
        super(StyleLoss, self).__init__()
        self.target = gram_matrix(target_feature).detach()

    def forward(self, input):
        G = gram_matrix(input)
        self.loss = F.mse_loss(G, self.target)
        return input

# %%
cnn = vgg19(weights=VGG19_Weights.DEFAULT).features.eval()

# %%
cnn_normalization_mean = torch.tensor([0.485, 0.456, 0.406])
cnn_normalization_std = torch.tensor([0.229, 0.224, 0.225])

# create a module to normalize input image so we can easily put it in a
# ``nn.Sequential``
class Normalization(nn.Module):
    def __init__(self, mean, std):
        super(Normalization, self).__init__()
        # .view the mean and std to make them [C x 1 x 1] so that they can
        # directly work with image Tensor of shape [B x C x H x W].
        # B is batch size. C is number of channels. H is height and W is width.
        self.mean = torch.tensor(mean).view(-1, 1, 1)
        self.std = torch.tensor(std).view(-1, 1, 1)

    def forward(self, img):
        # normalize ``img``
        return (img - self.mean) / self.std

# %%
# desired depth layers to compute style/content losses :
content_layers_default = ['conv_4']
style_layers_default = ['conv_1', 'conv_2', 'conv_3', 'conv_4', 'conv_5']

def get_style_model_and_losses(cnn, normalization_mean, normalization_std,
                               style_img, content_img,
                               content_layers=content_layers_default,
                               style_layers=style_layers_default):
    # normalization module
    normalization = Normalization(normalization_mean, normalization_std)

    # just in order to have an iterable access to or list of content/style
    # losses
    content_losses = []
    style_losses = []

    # assuming that ``cnn`` is a ``nn.Sequential``, so we make a new ``nn.Sequential``
    # to put in modules that are supposed to be activated sequentially
    model = nn.Sequential(normalization)

    i = 0  # increment every time we see a conv
    for layer in cnn.children():
        if isinstance(layer, nn.Conv2d):
            i += 1
            name = 'conv_{}'.format(i)
        elif isinstance(layer, nn.ReLU):
            name = 'relu_{}'.format(i)
            # The in-place version doesn't play very nicely with the ``ContentLoss``
            # and ``StyleLoss`` we insert below. So we replace with out-of-place
            # ones here.
            layer = nn.ReLU(inplace=False)
        elif isinstance(layer, nn.MaxPool2d):
            name = 'pool_{}'.format(i)
        elif isinstance(layer, nn.BatchNorm2d):
            name = 'bn_{}'.format(i)
        else:
            raise RuntimeError('Unrecognized layer: {}'.format(layer.__class__.__name__))

        model.add_module(name, layer)

        if name in content_layers:
            # add content loss:
            target = model(content_img).detach()
            content_loss = ContentLoss(target)
            model.add_module("content_loss_{}".format(i), content_loss)
            content_losses.append(content_loss)

        if name in style_layers:
            # add style loss:
            target_feature = model(style_img).detach()
            style_loss = StyleLoss(target_feature)
            model.add_module("style_loss_{}".format(i), style_loss)
            style_losses.append(style_loss)

    # now we trim off the layers after the last content and style losses
    for i in range(len(model) - 1, -1, -1):
        if isinstance(model[i], ContentLoss) or isinstance(model[i], StyleLoss):
            break

    model = model[:(i + 1)]

    return model, style_losses, content_losses

# %%
input_img = content_img.clone()
# if you want to use white noise by using the following code:
#
# .. code-block:: python
#
#    input_img = torch.randn(content_img.data.size())

# add the original input image to the figure:
plt.figure()
imshow(input_img, title='Input Image')

# %%
def get_input_optimizer(input_img):
    # this line to show that input is a parameter that requires a gradient
    optimizer = optim.LBFGS([input_img])
    return optimizer

# %%
def run_style_transfer(cnn, normalization_mean, normalization_std,
                       content_img, style_img, input_img, num_steps=1000,
                       style_weight=1000000, content_weight=1):
    """Run the style transfer."""
    print('Building the style transfer model..')
    model, style_losses, content_losses = get_style_model_and_losses(cnn,
        normalization_mean, normalization_std, style_img, content_img)

    # We want to optimize the input and not the model parameters so we
    # update all the requires_grad fields accordingly
    input_img.requires_grad_(True)
    # We also put the model in evaluation mode, so that specific layers
    # such as dropout or batch normalization layers behave correctly.
    model.eval()
    model.requires_grad_(False)

    optimizer = get_input_optimizer(input_img)

    print('Optimizing..')
    run = [0]
    while run[0] <= num_steps:

        def closure():
            # correct the values of updated input image
            with torch.no_grad():
                input_img.clamp_(0, 1)

            optimizer.zero_grad()
            model(input_img)
            style_score = 0
            content_score = 0

            for sl in style_losses:
                style_score += sl.loss
            for cl in content_losses:
                content_score += cl.loss

            style_score *= style_weight
            content_score *= content_weight

            loss = style_score + content_score
            loss.backward()

            run[0] += 5
            if run[0] % 1 == 0:
                print("run {}:".format(run))
                print('Style Loss : {:4f} Content Loss: {:4f}'.format(
                    style_score.item(), content_score.item()))
                print()

            return style_score + content_score

        optimizer.step(closure)

    # a last correction...
    with torch.no_grad():
        input_img.clamp_(0, 1)

    return input_img

# %%
output = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
                            content_img, style_img, input_img)

plt.figure()
imshow(output, title='Output Image')

# sphinx_gallery_thumbnail_number = 4
plt.ioff()
plt.show()
# Out:
# Building the style transfer model..
# Optimizing..
# run [5]:
# Style Loss : 18945.003906 Content Loss: 0.000000
#
# run [10]:
# Style Loss : 18918.427734 Content Loss: 0.000013
#
# run [15]:
# Style Loss : 10544.500000 Content Loss: 4.993783
#
# run [20]:
# Style Loss : 7444.949219 Content Loss: 6.678314
#
# run [25]:
# Style Loss : 5529.798340 Content Loss: 6.606834
#
# run [30]:
# Style Loss : 4222.113281 Content Loss: 7.314714
#
# run [35]:
# Style Loss : 3293.980957 Content Loss: 8.765893
#
# run [40]:
# Style Loss : 2614.811523 Content Loss: 10.572956
#
# run [45]:
# Style Loss : 2093.478760 Content Loss: 11.850085
#
# run [50]:
# Style Loss : 1720.555786 Content Loss: 12.689301
#
# run [55]:
# Style Loss : 1421.916748 Content Loss: 14.056344
#
# run [60]:
# Style Loss : 1182.117676 Content Loss: 15.809827
#
# run [65]:
# Style Loss : 1005.114380 Content Loss: 16.506313
#
# run [70]:
# Style Loss : 907.488037 Content Loss: 17.476461
#
# run [75]:
# Style Loss : 803.686646 Content Loss: 18.420971
#
# run [80]:
# Style Loss : 729.745728 Content Loss: 18.193439
#
# run [85]:
# Style Loss : 675.232300 Content Loss: 18.977907
#
# run [90]:
# Style Loss : 644.478027 Content Loss: 19.240065
#
# run [95]:
# Style Loss : 598.460083 Content Loss: 19.167561
#
# run [100]:
# Style Loss : 548.015015 Content Loss: 19.472059
#
# run [105]:
# Style Loss : 533.413574 Content Loss: 19.845467
#
# run [110]:
# Style Loss : 504.949707 Content Loss: 19.927996
#
# run [115]:
# Style Loss : 455.814575 Content Loss: 20.369099
#
# run [120]:
# Style Loss : 421.580444 Content Loss: 20.655743
#
# run [125]:
# Style Loss : 396.168549 Content Loss: 21.074654
#
# run [130]:
# Style Loss : 386.799652 Content Loss: 21.153612
#
# run [135]:
# Style Loss : 372.204010 Content Loss: 20.949635
#
# run [140]:
# Style Loss : 352.308624 Content Loss: 21.438784
#
# run [145]:
# Style Loss : 339.857208 Content Loss: 21.460995
#
# run [150]:
# Style Loss : 341.483368 Content Loss: 21.760637
#
# run [155]:
# Style Loss : 318.609528 Content Loss: 21.659084
#
# run [160]:
# Style Loss : 309.102753 Content Loss: 21.748428
#
# run [165]:
# Style Loss : 297.491699 Content Loss: 22.289787
#
# run [170]:
# Style Loss : 277.673035 Content Loss: 22.305887
#
# run [175]:
# Style Loss : 269.583252 Content Loss: 22.437080
#
# run [180]:
# Style Loss : 265.254364 Content Loss: 22.551765
#
# run [185]:
# Style Loss : 253.041016 Content Loss: 22.862425
#
# run [190]:
# Style Loss : 238.586182 Content Loss: 22.932629
#
# run [195]:
# Style Loss : 233.838196 Content Loss: 22.878555
#
# run [200]:
# Style Loss : 227.785217 Content Loss: 22.913752
#
# run [205]:
# Style Loss : 220.813599 Content Loss: 23.378838
#
# run [210]:
# Style Loss : 207.744308 Content Loss: 23.302092
#
# run [215]:
# Style Loss : 203.998260 Content Loss: 23.519115
#
# run [220]:
# Style Loss : 199.412704 Content Loss: 23.683575
#
# run [225]:
# Style Loss : 195.215439 Content Loss: 23.661812
#
# run [230]:
# Style Loss : 189.287643 Content Loss: 23.676619
#
# run [235]:
# Style Loss : 183.127258 Content Loss: 23.658800
#
# run [240]:
# Style Loss : 180.233536 Content Loss: 24.036810
#
# run [245]:
# Style Loss : 173.300171 Content Loss: 24.128059
#
# run [250]:
# Style Loss : 169.516891 Content Loss: 23.998371
#
# run [255]:
# Style Loss : 166.822403 Content Loss: 24.013512
#
# run [260]:
# Style Loss : 162.405075 Content Loss: 23.974640
#
# run [265]:
# Style Loss : 158.287476 Content Loss: 24.140894
#
# run [270]:
# Style Loss : 153.049179 Content Loss: 24.344475
#
# run [275]:
# Style Loss : 150.008499 Content Loss: 24.323944
#
# run [280]:
# Style Loss : 146.247742 Content Loss: 24.259844
#
# run [285]:
# Style Loss : 142.757919 Content Loss: 24.484131
#
# run [290]:
# Style Loss : 137.578552 Content Loss: 24.707018
#
# run [295]:
# Style Loss : 136.696747 Content Loss: 24.669764
#
# run [300]:
# Style Loss : 134.467285 Content Loss: 24.537468
#
# run [305]:
# Style Loss : 132.501877 Content Loss: 24.616991
#
# run [310]:
# Style Loss : 129.889297 Content Loss: 24.696135
#
# run [315]:
# Style Loss : 126.386963 Content Loss: 24.764372
#
# run [320]:
# Style Loss : 123.589622 Content Loss: 24.736090
#
# run [325]:
# Style Loss : 119.527245 Content Loss: 24.693199
#
# run [330]:
# Style Loss : 117.038986 Content Loss: 24.869545
#
# run [335]:
# Style Loss : 112.647018 Content Loss: 24.919844
#
# run [340]:
# Style Loss : 112.420792 Content Loss: 24.910328
#
# run [345]:
# Style Loss : 110.442558 Content Loss: 24.872301
#
# run [350]:
# Style Loss : 109.517906 Content Loss: 24.912590
#
# run [355]:
# Style Loss : 109.407928 Content Loss: 24.984613
#
# run [360]:
# Style Loss : 105.261414 Content Loss: 24.960243
#
# run [365]:
# Style Loss : 104.023575 Content Loss: 24.990461
#
# run [370]:
# Style Loss : 107.361717 Content Loss: 25.028231
#
# run [375]:
# Style Loss : 101.068062 Content Loss: 24.980080
#
# run [380]:
# Style Loss : 99.727661 Content Loss: 25.020409
#
# run [385]:
# Style Loss : 110.807274 Content Loss: 25.156034
#
# run [390]:
# Style Loss : 97.022331 Content Loss: 25.029961
#
# run [395]:
# Style Loss : 95.576706 Content Loss: 25.089159
#
# run [400]:
# Style Loss : 96.793381 Content Loss: 25.288622
#
# run [405]:
# Style Loss : 92.410507 Content Loss: 25.150042
#
# run [410]:
# Style Loss : 91.217339 Content Loss: 25.180298
#
# run [415]:
# Style Loss : 121.161575 Content Loss: 25.414558
#
# run [420]:
# Style Loss : 89.067062 Content Loss: 25.154875
#
# run [425]:
# Style Loss : 87.452141 Content Loss: 25.233032
#
# run [430]:
# Style Loss : 87.089912 Content Loss: 25.497313
#
# run [435]:
# Style Loss : 83.800354 Content Loss: 25.324034
#
# run [440]:
# Style Loss : 82.757568 Content Loss: 25.337776
#
# run [445]:
# Style Loss : 94.398216 Content Loss: 25.430494
#
# run [450]:
# Style Loss : 80.807701 Content Loss: 25.302549
#
# run [455]:
# Style Loss : 79.688110 Content Loss: 25.335468
#
# run [460]:
# Style Loss : 81.528709 Content Loss: 25.479185
#
# run [465]:
# Style Loss : 77.300591 Content Loss: 25.359400
#
# run [470]:
# Style Loss : 76.361130 Content Loss: 25.377489
#
# run [475]:
# Style Loss : 80.649933 Content Loss: 25.466541
#
# run [480]:
# Style Loss : 74.355293 Content Loss: 25.369781
#
# run [485]:
# Style Loss : 73.398621 Content Loss: 25.396706
#
# run [490]:
# Style Loss : 80.232948 Content Loss: 25.441103
#
# run [495]:
# Style Loss : 71.649559 Content Loss: 25.380236
#
# run [500]:
# Style Loss : 70.691360 Content Loss: 25.413177
#
# run [505]:
# Style Loss : 70.823288 Content Loss: 25.505243
#
# run [510]:
# Style Loss : 68.576012 Content Loss: 25.433647
#
# run [515]:
# Style Loss : 67.899696 Content Loss: 25.440723
#
# run [520]:
# Style Loss : 75.033577 Content Loss: 25.460737
#
# run [525]:
# Style Loss : 66.283463 Content Loss: 25.399107
#
# run [530]:
# Style Loss : 65.367188 Content Loss: 25.432617
#
# run [535]:
# Style Loss : 65.447472 Content Loss: 25.537769
#
# run [540]:
# Style Loss : 63.518391 Content Loss: 25.458830
#
# run [545]:
# Style Loss : 62.908672 Content Loss: 25.460463
#
# run [550]:
# Style Loss : 73.829811 Content Loss: 25.448433
#
# run [555]:
# Style Loss : 61.681305 Content Loss: 25.393042
#
# run [560]:
# Style Loss : 60.754059 Content Loss: 25.429094
#
# run [565]:
# Style Loss : 60.293236 Content Loss: 25.528429
#
# run [570]:
# Style Loss : 58.859138 Content Loss: 25.456354
#
# run [575]:
# Style Loss : 58.342571 Content Loss: 25.447477
#
# run [580]:
# Style Loss : 65.033821 Content Loss: 25.397535
#
# run [585]:
# Style Loss : 57.244987 Content Loss: 25.375216
#
# run [590]:
# Style Loss : 56.469856 Content Loss: 25.399786
#
# run [595]:
# Style Loss : 56.665054 Content Loss: 25.469637
#
# run [600]:
# Style Loss : 55.030613 Content Loss: 25.413073
#
# run [605]:
# Style Loss : 54.568123 Content Loss: 25.415905
#
# run [610]:
# Style Loss : 56.605602 Content Loss: 25.428699
#
# run [615]:
# Style Loss : 53.379124 Content Loss: 25.387672
#
# run [620]:
# Style Loss : 52.776371 Content Loss: 25.410273
#
# run [625]:
# Style Loss : 53.158001 Content Loss: 25.433275
#
# run [630]:
# Style Loss : 51.454590 Content Loss: 25.412964
#
# run [635]:
# Style Loss : 50.955589 Content Loss: 25.425079
#
# run [640]:
# Style Loss : 50.877998 Content Loss: 25.436237
#
# run [645]:
# Style Loss : 49.521027 Content Loss: 25.406811
#
# run [650]:
# Style Loss : 49.067211 Content Loss: 25.417046
#
# run [655]:
# Style Loss : 49.271961 Content Loss: 25.376482
#
# run [660]:
# Style Loss : 47.682350 Content Loss: 25.380196
#
# run [665]:
# Style Loss : 47.240513 Content Loss: 25.383492
#
# run [670]:
# Style Loss : 47.536640 Content Loss: 25.361296
#
# run [675]:
# Style Loss : 46.267635 Content Loss: 25.353077
#
# run [680]:
# Style Loss : 45.886517 Content Loss: 25.362047
#
# run [685]:
# Style Loss : 45.806190 Content Loss: 25.315901
#
# run [690]:
# Style Loss : 44.603504 Content Loss: 25.337841
#
# run [695]:
# Style Loss : 44.155960 Content Loss: 25.350153
#
# run [700]:
# Style Loss : 43.846687 Content Loss: 25.331127
#
# run [705]:
# Style Loss : 43.111309 Content Loss: 25.335138
#
# run [710]:
# Style Loss : 42.761806 Content Loss: 25.346233
#
# run [715]:
# Style Loss : 42.012188 Content Loss: 25.345598
#
# run [720]:
# Style Loss : 41.422188 Content Loss: 25.346901
#
# run [725]:
# Style Loss : 41.069027 Content Loss: 25.340868
#
# run [730]:
# Style Loss : 40.416000 Content Loss: 25.347961
#
# run [735]:
# Style Loss : 39.938976 Content Loss: 25.312452
#
# run [740]:
# Style Loss : 39.543049 Content Loss: 25.286175
#
# run [745]:
# Style Loss : 39.112755 Content Loss: 25.253992
#
# run [750]:
# Style Loss : 38.726852 Content Loss: 25.266182
#
# run [755]:
# Style Loss : 38.401386 Content Loss: 25.266973
#
# run [760]:
# Style Loss : 38.211235 Content Loss: 25.246489
#
# run [765]:
# Style Loss : 37.679913 Content Loss: 25.240273
#
# run [770]:
# Style Loss : 37.255398 Content Loss: 25.216078
#
# run [775]:
# Style Loss : 36.740486 Content Loss: 25.178625
#
# run [780]:
# Style Loss : 36.300789 Content Loss: 25.186230
#
# run [785]:
# Style Loss : 36.018822 Content Loss: 25.194860
#
# run [790]:
# Style Loss : 35.674313 Content Loss: 25.216925
#
# run [795]:
# Style Loss : 35.289062 Content Loss: 25.221336
#
# run [800]:
# Style Loss : 34.912537 Content Loss: 25.212633
#
# run [805]:
# Style Loss : 34.290615 Content Loss: 25.201220
#
# run [810]:
# Style Loss : 33.799244 Content Loss: 25.147509
#
# run [815]:
# Style Loss : 33.164982 Content Loss: 25.173012
#
# run [820]:
# Style Loss : 32.827354 Content Loss: 25.176073
#
# run [825]:
# Style Loss : 32.668270 Content Loss: 25.166979
#
# run [830]:
# Style Loss : 32.953663 Content Loss: 25.175756
#
# run [835]:
# Style Loss : 32.337353 Content Loss: 25.183916
#
# run [840]:
# Style Loss : 32.002186 Content Loss: 25.153229
#
# run [845]:
# Style Loss : 31.784945 Content Loss: 25.168243
#
# run [850]:
# Style Loss : 31.602194 Content Loss: 25.146490
#
# run [855]:
# Style Loss : 31.328306 Content Loss: 25.147310
#
# run [860]:
# Style Loss : 30.943960 Content Loss: 25.128401
#
# run [865]:
# Style Loss : 30.423794 Content Loss: 25.115070
#
# run [870]:
# Style Loss : 30.061041 Content Loss: 25.096081
#
# run [875]:
# Style Loss : 29.809269 Content Loss: 25.089052
#
# run [880]:
# Style Loss : 33.421429 Content Loss: 25.060163
#
# run [885]:
# Style Loss : 29.851988 Content Loss: 25.047899
#
# run [890]:
# Style Loss : 29.444223 Content Loss: 25.099524
#
# run [895]:
# Style Loss : 29.107389 Content Loss: 25.118425
#
# run [900]:
# Style Loss : 28.822134 Content Loss: 25.115166
#
# run [905]:
# Style Loss : 28.473738 Content Loss: 25.090818
#
# run [910]:
# Style Loss : 28.112837 Content Loss: 25.070213
#
# run [915]:
# Style Loss : 28.068998 Content Loss: 25.050299
#
# run [920]:
# Style Loss : 27.609327 Content Loss: 25.065746
#
# run [925]:
# Style Loss : 27.420938 Content Loss: 25.067732
#
# run [930]:
# Style Loss : 27.243105 Content Loss: 25.052357
#
# run [935]:
# Style Loss : 27.025803 Content Loss: 25.055153
#
# run [940]:
# Style Loss : 26.801947 Content Loss: 25.049400
#
# run [945]:
# Style Loss : 26.595318 Content Loss: 25.027271
#
# run [950]:
# Style Loss : 26.402937 Content Loss: 25.023993
#
# run [955]:
# Style Loss : 26.205929 Content Loss: 25.007744
#
# run [960]:
# Style Loss : 25.992765 Content Loss: 24.994474
#
# run [965]:
# Style Loss : 25.748775 Content Loss: 24.991724
#
# run [970]:
# Style Loss : 25.573355 Content Loss: 24.978392
#
# run [975]:
# Style Loss : 25.324690 Content Loss: 24.981142
#
# run [980]:
# Style Loss : 25.163937 Content Loss: 24.973572
#
# run [985]:
# Style Loss : 24.910875 Content Loss: 24.949837
#
# run [990]:
# Style Loss : 24.723503 Content Loss: 24.948927
#
# run [995]:
# Style Loss : 24.536673 Content Loss: 24.942924
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 output = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
#       2                             content_img, style_img, input_img)
#       4 plt.figure()
#       5 imshow(output, title='Output Image')
#
# Cell In[31], line 53, in run_style_transfer(cnn, normalization_mean, normalization_std, content_img, style_img, input_img, num_steps, style_weight, content_weight)
#      49             print()
#      51         return style_score + content_score
# ---> 53     optimizer.step(closure)
#      55 # a last correction...
#      56 with torch.no_grad():
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/optim/optimizer.py:487, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     482         else:
#     483             raise RuntimeError(
#     484                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     485             )
# --> 487 out = func(*args, **kwargs)
#     488 self._optimizer_step_code()
#     490 # call optimizer step post hooks
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/optim/lbfgs.py:457, in LBFGS.step(self, closure)
#     452 if n_iter != max_iter:
#     453     # re-evaluate function only if not in last iteration
#     454     # the reason we do this: in a stochastic setting,
#     455     # no use to re-evaluate that function here
#     456     with torch.enable_grad():
# --> 457         loss = float(closure())
#     458     flat_grad = self._gather_flat_grad()
#     459     opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# Cell In[31], line 42, in run_style_transfer.<locals>.closure()
#      39 content_score *= content_weight
#      41 loss = style_score + content_score
# ---> 42 loss.backward()
#      44 run[0] += 5
#      45 if run[0] % 1 == 0:
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/_tensor.py:572, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     528 r"""Computes the gradient of current tensor wrt graph leaves.
#     529
#     530 The graph is differentiated using the chain rule. If the tensor is
#    (...)
#     569         used to compute the :attr:`tensors`.
#     570 """
#     571 if has_torch_function_unary(self):
# --> 572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#     575         self,
#     576         gradient=gradient,
#     577         retain_graph=retain_graph,
#     578         create_graph=create_graph,
#     579         inputs=inputs,
#     580     )
#     581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/overrides.py:1717, in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1713 if _is_torch_function_mode_enabled():
#    1714     # if we're here, the mode must be set to a TorchFunctionStackMode
#    1715     # this unsets it and calls directly into TorchFunctionStackMode's torch function
#    1716     with _pop_mode_temporarily() as mode:
# -> 1717         result = mode.__torch_function__(public_api, types, args, kwargs)
#    1718     if result is not NotImplemented:
#    1719         return result
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/utils/_device.py:106, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#     104 if func in _device_constructors() and kwargs.get('device') is None:
#     105     kwargs['device'] = self.device
# --> 106 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Load the pre-trained VGG19 model
model = tf.keras.applications.VGG19(include_top=False, weights='imagenet')

# Define content and style images
style_img = image_loader("./images/pablo_picasso.jpg")
content_img = image_loader("./images/chanel_bag_2.jpg")

# Define layers for style and content representations
content_layers = ['block5_conv2'] 

style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1', 
                'block4_conv1', 
                'block5_conv1']

num_content_layers = len(content_layers)
num_style_layers = len(style_layers)

# Build the model
model = build_model(vgg, style_layers, content_layers)

# Define the target style and content
style_targets = model(style_image)['style']
content_targets = model(content_image)['content']

# Define your cost functions
style_weight = 1e-2
content_weight = 1e4

# Optimize the image using gradient descent
image = tf.Variable(content_image)  # Start with the content image
optimizer = tf.optimizers.Adam(learning_rate=0.02, beta_1=0.99, epsilon=1e-1)

iterations = 1000
for i in range(1, iterations + 1):
    train_step(image, model, style_weight, content_weight)
    if i % 100 == 0:
        plt.imshow(np.array(image))
        plt.show()
